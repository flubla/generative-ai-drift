# %% [markdown]
# Nothing special here - just a file to experiment with.
#
# If you have some data in weaviate, no matter the schema,
# you can run this script to view and explore the data in nomic ATLAS.

# %%
import weaviate
import json

print("Let's a go!")
client = weaviate.Client("http://localhost:8080")
print("Client created")

# list the schemas
schema = client.schema.get()
print(json.dumps(schema, indent=4))

result = (
    client.query
    .aggregate("DriftBenchmark")
    .with_fields("meta { count }")
    .do()
)

print(json.dumps(result, indent=4))
# Out:
# Let's a go!
# Client created
# {
#     "classes": [
#         {
#             "class": "DriftBenchmark",
#             "invertedIndexConfig": {
#                 "bm25": {
#                     "b": 0.75,
#                     "k1": 1.2
#                 },
#                 "cleanupIntervalSeconds": 60,
#                 "stopwords": {
#                     "additions": null,
#                     "preset": "en",
#                     "removals": null
#                 }
#             },
#             "moduleConfig": {
#                 "text2vec-transformers": {
#                     "model": "sentence-transformers/multi-qa-MiniLM-L6-cos-v1",
#                     "options": {
#                         "waitForModel": false
#                     },
#                     "poolingStrategy": "masked_mean",
#                     "vectorizeClassName": false
#                 }
#             },
#             "multiTenancyConfig": {
#                 "enabled": false
#             },
#             "properties": [
#                 {
#                     "dataType": [
#                         "int"
#                     ],
#                     "description": "The number of tokens in the prompt",
#                     "indexFilterable": true,
#                     "indexSearchable": false,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "prompt_token_len"
#                 },
#                 {
#                     "dataType": [
#                         "int"
#                     ],
#                     "description": "The number of sentences in the prompt",
#                     "indexFilterable": true,
#                     "indexSearchable": false,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "prompt_sent_len"
#                 },
#                 {
#                     "dataType": [
#                         "text"
#                     ],
#                     "description": "The text sent to the API.",
#                     "indexFilterable": true,
#                     "indexSearchable": true,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "prompt",
#                     "tokenization": "word"
#                 },
#                 {
#                     "dataType": [
#                         "int"
#                     ],
#                     "description": "The number of tokens in the completion",
#                     "indexFilterable": true,
#                     "indexSearchable": false,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "completion_token_len"
#                 },
#                 {
#                     "dataType": [
#                         "int"
#                     ],
#                     "description": "The number of sentences in the completion",
#                     "indexFilterable": true,
#                     "indexSearchable": false,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "completion_sent_len"
#                 },
#                 {
#                     "dataType": [
#                         "text"
#                     ],
#                     "description": "This is the value returned by the API and used to test similarity",
#                     "indexFilterable": true,
#                     "indexSearchable": true,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": false,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "completion",
#                     "tokenization": "word"
#                 },
#                 {
#                     "dataType": [
#                         "date"
#                     ],
#                     "description": "Just the date_time that the record was made.",
#                     "indexFilterable": true,
#                     "indexSearchable": false,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "date_time"
#                 },
#                 {
#                     "dataType": [
#                         "text"
#                     ],
#                     "description": "A v4 UUID",
#                     "indexFilterable": true,
#                     "indexSearchable": true,
#                     "moduleConfig": {
#                         "text2vec-transformers": {
#                             "skip": true,
#                             "vectorizePropertyName": false
#                         }
#                     },
#                     "name": "chat_id",
#                     "tokenization": "word"
#                 }
#             ],
#             "replicationConfig": {
#                 "factor": 1
#             },
#             "shardingConfig": {
#                 "virtualPerPhysical": 128,
#                 "desiredCount": 1,
#                 "actualCount": 1,
#                 "desiredVirtualCount": 128,
#                 "actualVirtualCount": 128,
#                 "key": "_id",
#                 "strategy": "hash",
#                 "function": "murmur3"
#             },
#             "vectorIndexConfig": {
#                 "skip": false,
#                 "cleanupIntervalSeconds": 300,
#                 "maxConnections": 64,
#                 "efConstruction": 128,
#                 "ef": -1,
#                 "dynamicEfMin": 100,
#                 "dynamicEfMax": 500,
#                 "dynamicEfFactor": 8,
#                 "vectorCacheMaxObjects": 1000000000000,
#                 "flatSearchCutoff": 40000,
#                 "distance": "cosine",
#                 "pq": {
#                     "enabled": false,
#                     "bitCompression": false,
#                     "segments": 0,
#                     "centroids": 256,
#                     "trainingLimit": 100000,
#                     "encoder": {
#                         "type": "kmeans",
#                         "distribution": "log-normal"
#                     }
#                 }
#             },
#             "vectorIndexType": "hnsw",
#             "vectorizer": "text2vec-transformers"
#         }
#     ]
# }
# {
#     "data": {
#         "Aggregate": {
#             "DriftBenchmark": [
#                 {
#                     "meta": {
#                         "count": 25
#                     }
#                 }
#             ]
#         }
#     }
# }

# %%
import weaviate
from nomic import AtlasProject
import numpy as np
import nomic
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv('NOMIC_API_KEY')
nomic.login(api_key)  
nomic.__init__(name="DriftDbDev0")

print("Let's a go!")

print("Connecting to weaviate instance on localhost:8080...")
client = weaviate.Client("http://localhost:8080")
print("Client created")

schema = client.schema.get()

classes = []
props = []
for c in schema["classes"]:
    classes.append(c["class"])
    temp = []
    for p in c["properties"]:
        if p["dataType"] == ["text"]:
            temp.append(p["name"])
    props.append(temp)


def get_batch_with_cursor(
    client, class_name, class_properties, batch_size, cursor=None
):
    query = (
        client.query.get(class_name, class_properties)
        .with_additional(["vector", "id"])
        .with_limit(batch_size)
    )

    if cursor is not None:
        return query.with_after(cursor).do()
    else:
        return query.do()


for c, p in zip(classes, props):
    project = AtlasProject(
        name="BenchmarkDev0",
        unique_id_field="id",
        modality="embedding",
    )
    count = 0
    cursor = None
    while True:
        response = get_batch_with_cursor(client, c, p, 10000, cursor)
        count += 1
        if len(response["data"]["Get"][c]) == 0:
            break
        cursor = response["data"]["Get"][c][-1]["_additional"]["id"]
        vectors = []
        for i in response["data"]["Get"][c]:
            vectors.append(i["_additional"]["vector"])

        embeddings = np.array(vectors)
        data = []
        not_data = ["_additional"]
        un_data = ["vector"]
        for i in response["data"]["Get"][c]:
            j = {key: value for key, value in i.items() if key not in not_data}
            k = {
                key: value
                for key, value in i["_additional"].items()
                if key not in un_data
            }
            j = j | k
            data.append(j)
        with project.wait_for_project_lock():
            project.add_embeddings(
                embeddings=embeddings,
                data=data,
            )
    project.rebuild_maps()
    project.create_index(
        name=c,
        colorable_fields=p,
        build_topic_model=True,
    )
# Out:
# Let's a go!
# Connecting to weaviate instance on localhost:8080...
# Client created
# 2023-08-02 23:03:48.677 | INFO     | nomic.project:_create_project:779 - Creating project `BenchmarkDev1` in organization `zaidanseiko`
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 81
#      79         data.append(j)
#      80     with project.wait_for_project_lock():
# ---> 81         project.add_embeddings(
#      82             embeddings=embeddings,
#      83             data=data,
#      84         )
#      85 project.rebuild_maps()
#      86 project.create_index(
#      87     name=c,
#      88     colorable_fields=p,
#      89     build_topic_model=True,
#      90 )
#
# File c:\Users\kevin\miniconda3\Lib\site-packages\nomic\project.py:1271, in AtlasProject.add_embeddings(***failed resolving arguments***)
#    1267 pyarrow_embeddings = pa.FixedSizeListArray.from_arrays(embeddings.reshape((-1)), embeddings.shape[1])
#    1269 data_with_embeddings = tb.append_column("_embeddings", pyarrow_embeddings)
# -> 1271 self._add_data(data_with_embeddings, pbar=pbar)
#
# File c:\Users\kevin\miniconda3\Lib\site-packages\nomic\project.py:1306, in AtlasProject._add_data(self, data, pbar)
#    1303 if bytesize / n_chunks > 4_000_000:
#    1304     shard_size = int(np.ceil(nrow / (bytesize / 4_000_000)))
# -> 1306 data = self._validate_and_correct_arrow_upload(
#    1307     data=data,
#    1308     project=self,
#    1309 )
#    1311 upload_endpoint = "/v1/project/data/add/arrow"
#    1313 # Actually do the upload
#
# File c:\Users\kevin\miniconda3\Lib\site-packages\nomic\project.py:216, in AtlasClass._validate_and_correct_arrow_upload(self, data, project)
#     213     seen.add(col.lower())
#     215 if project.schema is None:
# --> 216     project._schema = convert_pyarrow_schema_for_atlas(data.schema)
#     217 # Reformat to match the schema of the project.
#     218 # This includes shuffling the order around if necessary,
#     219 # filling in nulls, etc.
#     220 reformatted = {}
#
# File c:\Users\kevin\miniconda3\Lib\site-packages\nomic\data_inference.py:51, in convert_pyarrow_schema_for_atlas(schema)
#      49         types[field.name] = 'date'
#      50     else:
# ---> 51         raise TypeError(f"Unknown type: {field.name} {field.type}")
#      52 usertypes = {k: permitted_types[v] for k, v in types.items()}
#      54 return pa.schema({**usertypes, **whitelist})
#
# TypeError: Unknown type: completion_sent_len null
